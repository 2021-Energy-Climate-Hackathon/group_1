# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error
from datetime import datetime

# %%
# load in dataset
# read in UK t2m & NAO data
df = pd.read_csv("country_data/ERA5_hourly_UK_old.csv")
df.columns = ["date_time","t2m","ssrd","msl","nao", "w10","w100"]
df.head()
# Out:
#              date_time       t2m     ssrd          msl   nao       w10  \
# 0  1979-01-01 00:00:00 -5.702784 -32767.0  1014.010319 -1.38  0.539450
# 1  1979-01-01 01:00:00 -5.507162 -32767.0  1014.724101 -1.38  0.756348
# 2  1979-01-01 02:00:00 -5.664224 -32767.0  1015.209416 -1.38  1.106655
# 3  1979-01-01 03:00:00 -5.944852 -32767.0  1015.758926 -1.38  1.299900
# 4  1979-01-01 04:00:00 -5.952020 -32767.0  1015.954954 -1.38  1.383135
#
#        w100
# 0  1.686726
# 1  1.752340
# 2  2.131312
# 3  2.487398
# 4  2.694151

# %%
# add week
df["week"] = pd.to_numeric(pd.to_datetime(df.date_time).dt.strftime("%U"))

# %% [markdown]
# # Preprocessing
#
# ### Split Train/test

# %%
# calculate daily values
df.date_time = pd.to_datetime(df.date_time)
df_daily = df.groupby(df.date_time.dt.date).mean()
df_daily["t2mmax"] = t2mmax = df.t2m.groupby(df.date_time.dt.date).max()
df_daily["t2mmin"] = df.t2m.groupby(df.date_time.dt.date).min()

# set X equal to df_daily
X = df_daily

# %%
# create 24-hour t2m arrays as target variable
Y_list = []
for i in range(int(len(df)/24)):
    Y_list.append(df.t2m.iloc[(i*24):(i*24+24)].values)
Y = np.array(Y_list)

# add date_time index
y = pd.DataFrame(Y,index=df_daily.index)

# %% [markdown]
# ### Visualization of independent vars

# %%
X.hist(figsize=(10,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f70905a4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70a7d0ae80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f707cc75400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f707cc98978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f707cc3def0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f707cbe8470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f707cc0a9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f707cbaef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f707cbaefd0>]],
#       dtype=object)

# %% [markdown]
# Mostly normal distributions of variables of interest, except ssrd/tp.

# %%
df.ssrd.plot(figsize=(10,5))

# %% [markdown]
# Remove outliers from ssrd/tp (first 24 hours).

# %%
# remove outliers
X.ssrd[X.ssrd<-5000]=0

# ssrd NaN values convert to 0
X.ssrd = X.ssrd.fillna(0)

# produce ssrd plot
X[["ssrd"]].hist()
# Out:
# /opt/jaspy/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7090c76470>]],
#       dtype=object)

# %% [markdown]
# Split train/test

# %%
# split train/test 70/30
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3,random_state = 10,shuffle=False)

# create a dataframe of the hours for plotting purposes
X_test.index = pd.to_datetime(X_test.index)
X_test_hours = X_test.resample("1H").pad().index

# %% [markdown]
# ### Modeling
#
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# produce linear regression
reg = LinearRegression().fit(X_train, y_train)
pred_reg = reg.predict(X_test)

# %%
# metrics
r2_reg = r2_score(y_test,pred_reg)
mae_reg = mean_absolute_error(y_test,pred_reg)

print("R2-score: ",r2_reg)
print("MAE-score: ",mae_reg)
# Out:
# R2-score:  0.9788673538277753
# MAE-score:  0.4251066266580952

# %%
# plot results
plt.scatter(y_test.values.flatten(),pred_reg.flatten())
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted: Linear Regression")
plt.rcParams["figure.figsize"] = (20,5)

# %%
plt.scatter(np.arange(0,50*24,1),y_test.values[300:350])
plt.scatter(np.arange(0,50*24,1),pred_reg[300:350])
plt.xlabel("Hour")
plt.title("Random Sample of Predictions T2m: Linear Regression")
plt.legend(["Actual","Predicted"])

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100).fit(X_train,y_train)
pred_rf = rf.predict(X_test)

# %%
# metrics
r2_rf = r2_score(y_test,pred_rf)
mae_rf = mean_absolute_error(y_test,pred_rf)

print("R2-score: ",r2_rf)
print("MAE-score: ",mae_rf)
# Out:
# R2-score:  0.9809835680463556
# MAE-score:  0.38895249027228873

# %%
n_estimators = []
mae = []
for i in range(1,100,10):
    rf = RandomForestRegressor(n_estimators=i).fit(X_train,y_train)
    pred_rf = rf.predict(X_test)
    n_estimators.append(i)
    mae.append(mean_absolute_error(y_test,pred_rf)) 
n_estimators = np.array(n_estimators)
mae = np.array(mae)

plt.plot(n_estimators,mse)
plt.title("Scree Plot: Random Forest")
plt.xlabel("n_estimators")
plt.ylabel("MAE")

# %% [markdown]
# Maximum number of trees can be set to 100 as there is little computational cost.

# %%
plt.scatter(np.arange(0,50*24,1),y_test.values[4000:4050])
plt.scatter(np.arange(0,50*24,1),pred_rf[4000:4050])
plt.xlabel("Hour")
plt.title("Random Sample of Predictions T2m: Random Forest")
plt.legend(["Actual","Predicted"])
plt.rcParams["figure.figsize"] = (20,5)

# %% [markdown]
# ### Analyze Best Performer
#
# The best performer was Random Forest.
#
# Below is a visual representation of the seasonal error.

# %%
se = (pred_rf - y_test)**2
se.index = pd.to_datetime(se.index)
mse_by_week = se.groupby(se.index.week).mean().mean(axis=1)
plt.plot(np.arange(0,53,1),mse_by_week.values.flatten(),linewidth=5)
plt.title("Weekly MSE Distribution: RF Predictions")
plt.xlabel("Week of Year")
plt.ylabel("MSE")
# Out:
# Text(0, 0.5, 'MSE')

# %%
se = (pred_rf - y_test)**2
se.index = pd.to_datetime(se.index)
mse_by_hour = se.groupby(se.index.hour).mean()
plt.plot(np.arange(0,24,1),mse_by_hour.values.flatten(),linewidth=5)
plt.title("Diurnal MSE Distribution: RF Predictions")
plt.xlabel("Hour of Day")
plt.ylabel("MSE")
# Out:
# Text(0, 0.5, 'MSE')

# %% [markdown]
# Found that winter weeks have higher MSE in comparison to summer months.

# %%
# generate summer/winter comparisons
y_d14_summer = y_test.iloc[60:74]
y_d14_winter = y_test.iloc[230:244]
pred_d14_summer = pred_rf[60:74]
pred_d14_winter = pred_rf[230:244]

plt.scatter(np.arange(0,14*24,1),y_d14_summer)
plt.scatter(np.arange(0,14*24,1),pred_d14_summer)
plt.xlabel("Hour")
plt.title("2-Week Summer Period Predictions (Jul 26 - Aug 8, 2008)")
plt.legend(["Actual","Predicted"])

# %%
plt.scatter(np.arange(0,14*24,1),y_d14_winter)
plt.scatter(np.arange(0,14*24,1),pred_d14_winter)
plt.xlabel("Hour")
plt.title("2-Week Winter Period Predictions (Jan 12 - Jan 25, 2009)")
plt.legend(["Actual","Predicted"])

# %% [markdown]
# Clearly the model has issues with the extreme fluctuations of temperatures across the UK in the winter months, with predictions unable to capture the variability of the diurnal cycle. Summer months exhibit a more constant diurnal cycle with much better predictions.

# %%
feature_names = X.columns
importances = rf.feature_importances_
std = np.std([
    tree.feature_importances_ for tree in rf.estimators_], axis=0)
forest_importances = pd.Series(importances, index=feature_names)
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
forest_importances.plot.bar( ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# - Try lag of previous day (tmean,tmin) and next day (tmean,tmin)
# - Feature importance
# - Gradient previous day/next day
#
# ### Random Forest with Lag Variables

# %%
# add lag features
X["t2min_previous"] = X.t2mmin.shift(1)
X["t2m_previous"] = X.t2m.shift(1)
X["t2min_next"] = X.t2mmin.shift(-1)
X["t2m_next"] = X.t2m.shift(-1)

# fill the NaN shifted row with 0
X = X.fillna(0)

# %% [markdown]
# Split train/test

# %%
# split train/test 70/30
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3,random_state = 10,shuffle=False)

# create a dataframe of the hours for plotting purposes
X_test.index = pd.to_datetime(X_test.index)
X_test_hours = X_test.resample("1H").pad().index

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100).fit(X_train,y_train)
pred_rf = rf.predict(X_test)

# %%
# metrics
r2_rf = r2_score(y_test,pred_rf)
mae_rf = mean_absolute_error(y_test,pred_rf)

print("R2-score: ",r2_rf)
print("MAE-score: ",mae_rf)
# Out:
# R2-score:  0.9883624977095717
# MAE-score:  0.3134555431238394

# %%
# generate summer/winter comparisons
y_d14_summer = y_test.iloc[60:74]
y_d14_winter = y_test.iloc[230:244]
pred_d14_summer = pred_rf[60:74]
pred_d14_winter = pred_rf[230:244]


plt.scatter(np.arange(0,14*24,1),y_d14_winter)
plt.scatter(np.arange(0,14*24,1),pred_d14_winter)
plt.xlabel("Hour")
plt.title("2-Week Winter Period Predictions (Jan 12 - Jan 25, 2009)")
plt.legend(["Actual","Predicted"])

# %%
feature_names = X.columns
importances = rf.feature_importances_
std = np.std([
    tree.feature_importances_ for tree in rf.estimators_], axis=0)
forest_importances = pd.Series(importances, index=feature_names)
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
forest_importances.plot.bar( ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# Overall, adding the previous day inputs proved successful in slightly improving the model performance. 0z and 23z day temperatures are better connected than the previous model, especially during the winter months. In addition, MSL/NAO/w10/W100 are not beneficial parameters to the model.
#
# ### Case Studies

# %%
def RMS_based_eval(timeseries_for_eval,field,case_no,method_str):

    ''''
    timeseries_for_eval [array] must be the appropriate length for case study evaluation 
    Case1 = 168 hours
    Case2 = 216 hours
    Case3 = 672 hours
    field [str] must either be 'T2m', 'speed10m' , or 'rsds'
    case no [str] must be either 1,2 or 3.
    method_str [str] what you'd like it referred to as.
    '''
    
    obs = np.loadtxt('/gws/pw/j05/cop26_hackathons/oxford/Group_folders/group_1/case_studies/Case_' + case_no + '_' + field + '.dat')
    
    obs_date = np.load('/gws/pw/j05/cop26_hackathons/oxford/Group_folders/group_1/case_studies/Case_' + case_no + '_date.npy')
    MAE = np.mean(obs - timeseries_for_eval)
    RMS = np.sqrt(np.nanmean((obs - timeseries_for_eval)**2))
    
    fig = plt.figure(figsize=(12,4))
    plt.plot(obs_date,obs,color='k',label='ERA5 obs')
    if field == 'T2m':
        plt.plot(obs_date,timeseries_for_eval,color='r',label=method_str)
        plt.ylabel('2m temperature ($^{o}$C)',fontsize=14)
        plt.title('Case study ' + case_no )
        plt.xlabel('MAE = ' + str(MAE) + ' , RMS = ' + str(RMS))
    if field == 'speed10m':
        plt.plot(obs_date,timeseries_for_eval,color='b',label=method_str)
        plt.ylabel('10m wind speed (ms$^{-1}$)',fontsize=14)
        plt.title('Case study ' + case_no)
    if field == 'rsds':
        plt.plot(obs_date,timeseries_for_eval,color='gold',label=method_str)
        plt.ylabel('Surface shortwave radiation (Wm$^{-2}$)',fontsize=14)
        plt.title('Case study ' + case_no )
    plt.legend(frameon=False)
    plt.show()
    return([MAE, RMS])

# %%
# index y_test to determine dates for case studies
days = pd.to_datetime(y_test.index)
index_case1 = np.where((days>=datetime(2019,11,18)) & (days<=datetime(2019,11,24)))
input_case1 = pred_rf[index_case1].flatten()

index_case2 = np.where((days>=datetime(2020,7,1)) & (days<=datetime(2020,7,9)))
input_case2 = pred_rf[index_case2].flatten()

index_case3 = np.where((days>=datetime(2018,2,20)) & (days<=datetime(2018,3,19)))
input_case3 = pred_rf[index_case3].flatten()

# %%
RMS_based_eval(input_case1,"T2m","1","Random Forest")
# Out:
# [-0.31791321458580224, 0.5465215896957865]

# %%
RMS_based_eval(input_case2,"T2m","2","Random Forest")
# Out:
# [0.5658148357990186, 0.789955056414401]

# %%
RMS_based_eval(input_case3,"T2m","3","Random Forest")
# Out:
# [-0.15152432434833005, 0.7110760077035378]

# %% [markdown]
# ### Random Forest w/ precipitation & cloud cover
# - collect precipitation, cloud cover

# %%
# load in dataset
# read in UK t2m & NAO data
df2 = pd.read_csv("country_data/ERA5_hourly_UK.csv")
df2.columns = ["date_time","t2m","ssrd","msl","nao", "w10","w100","tcc","tp"]
# add week
df2["week"] = pd.to_numeric(pd.to_datetime(df2.date_time).dt.strftime("%U"))

df2.head()
# Out:
#              date_time       t2m     ssrd          msl   nao       w10  \
# 0  1979-01-01 00:00:00 -5.702784 -32767.0  1014.010319 -1.38  0.539450
# 1  1979-01-01 01:00:00 -5.507162 -32767.0  1014.724101 -1.38  0.756348
# 2  1979-01-01 02:00:00 -5.664224 -32767.0  1015.209416 -1.38  1.106655
# 3  1979-01-01 03:00:00 -5.944852 -32767.0  1015.758926 -1.38  1.299900
# 4  1979-01-01 04:00:00 -5.952020 -32767.0  1015.954954 -1.38  1.383135
#
#        w100       tcc          tp  week
# 0  1.686726  0.596991 -32767000.0     0
# 1  1.752340  0.616364 -32767000.0     0
# 2  2.131312  0.609257 -32767000.0     0
# 3  2.487398  0.633477 -32767000.0     0
# 4  2.694151  0.638393 -32767000.0     0

# %%
# calculate daily values
df2.date_time = pd.to_datetime(df2.date_time)
df2_daily = df2.groupby(df2.date_time.dt.date).mean()
df2_daily["t2mmax"] = t2mmax = df2.t2m.groupby(df2.date_time.dt.date).max()
df2_daily["t2mmin"] = df2.t2m.groupby(df2.date_time.dt.date).min()

# set X equal to df_daily
X2 = df2_daily

# remove outliers
X2.ssrd[X2.ssrd<-5000]=0
X2.tp[X2.tp<-1000]=0

# shows that there is 725 null precip values
#print("Number of null precip values",df.tp.isnull().sum())

# ssrd/tp NaN values convert to 0
X2.ssrd = X2.ssrd.fillna(0)
X2.tp = X2.tp.fillna(0)

# produce ssrd plot
X2[["ssrd","tp"]].hist()
# Out:
# /opt/jaspy/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /opt/jaspy/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f707a910198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7091511940>]],
#       dtype=object)

# %%
# create 24-hour t2m arrays as target variable
Y2_list = []
for i in range(int(len(df2)/24)):
    Y2_list.append(df2.t2m.iloc[(i*24):(i*24+24)].values)
Y2 = np.array(Y2_list)

# add date_time index
y2 = pd.DataFrame(Y2,index=df2_daily.index)

# %%
# add lag features
X2["t2min_previous"] = X2.t2mmin.shift(1)
X2["t2m_previous"] = X2.t2m.shift(1)
X2["t2min_next"] = X2.t2mmin.shift(-1)
X2["t2m_next"] = X2.t2m.shift(-1)

# fill the NaN shifted row with 0
X2 = X2.fillna(0)

# %%
# split train/test 70/30
X2_train, X2_test, y2_train, y2_test = train_test_split(X2,y2, test_size=0.3,random_state = 10,shuffle=False)

# create a dataframe of the hours for plotting purposes
X2_test.index = pd.to_datetime(X2_test.index)
X2_test_hours = X2_test.resample("1H").pad().index

# %% [markdown]
# ### Random Forest Modeling w/Lag & Cloud Cover/Precip

# %%
from sklearn.ensemble import RandomForestRegressor

rf2 = RandomForestRegressor(n_estimators=100).fit(X2_train,y2_train)
pred_rf2 = rf2.predict(X2_test)

# %%
# metrics
r2_rf2 = r2_score(y2_test,pred_rf2)
mae_rf2 = mean_absolute_error(y2_test,pred_rf2)

print("R2-score: ",r2_rf2)
print("MAE-score: ",mae_rf2)
# Out:
# R2-score:  0.9884926172964775
# MAE-score:  0.31194108016110156

# %% [markdown]
# This is a very slight improvement from above:
#
# R2-score:  0.9883624977095717
#
# MAE-score:  0.3134555431238394

# %%
feature_names2 = X2.columns
importances2 = rf2.feature_importances_
std = np.std([
    tree.feature_importances_ for tree in rf2.estimators_], axis=0)
forest_importances2 = pd.Series(importances2, index=feature_names2)
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
forest_importances2.plot.bar( ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
print(forest_importances2)
# Out:
# t2m               0.957478
# ssrd              0.001618
# msl               0.000499
# nao               0.000433
# w10               0.000626
# w100              0.000669
# tcc               0.001059
# tp                0.000744
# week              0.000985
# t2mmax            0.016166
# t2mmin            0.009235
# t2min_previous    0.002733
# t2m_previous      0.000960
# t2min_next        0.002912
# t2m_next          0.003882
# dtype: float64

# %% [markdown]
# Overall, tcc and tp are not significant predictors of the hourly diurnal cycle of temperature.

# %%
# index y_test to determine dates for case studies
days = pd.to_datetime(y2_test.index)
index_case1 = np.where((days>=datetime(2019,11,18)) & (days<=datetime(2019,11,24)))
input_case1 = pred_rf2[index_case1].flatten()

index_case2 = np.where((days>=datetime(2020,7,1)) & (days<=datetime(2020,7,9)))
input_case2 = pred_rf2[index_case2].flatten()

index_case3 = np.where((days>=datetime(2018,2,20)) & (days<=datetime(2018,3,19)))
input_case3 = pred_rf2[index_case3].flatten()

# %% [markdown]
# ### Case Studies

# %%
RMS_based_eval(input_case1,"T2m","1","Random Forest")
# Out:
# [-0.32526390078861933, 0.5562721532573004]

# %% [markdown]
# Model without tp/tcc:
#
# [-0.31791321458580224, 0.5465215896957865]

# %%
RMS_based_eval(input_case2,"T2m","2","Random Forest")
# Out:
# [0.566537816374845, 0.7967349479755063]

# %% [markdown]
# Model without tp/tcc:
#
# [0.5658148357990186, 0.789955056414401]

# %%
RMS_based_eval(input_case3,"T2m","3","Random Forest")
# Out:
# [-0.15262294630215095, 0.7091807707844384]

# %% [markdown]
# Model without tp/tcc:
#
# [-0.15152432434833005, 0.7110760077035378]
#
#
# Overall precipitation and cloud cover did not significantly improve model performance in the 3 case studies. Values varied between +-1%.

# %% [markdown]
# ### Feature Reduction
#
# Removal of TP, msl, nao, w10, w100 from model.

# %%
# features of interest
vars = ["t2m","ssrd","tcc","week","t2mmax","t2mmin","t2min_previous","t2m_previous","t2min_next","t2m_next"]

rf3 = RandomForestRegressor(n_estimators=100).fit(X2_train[vars],y2_train)
pred_rf3 = rf3.predict(X2_test[vars])

# %%
# metrics
r2_rf3 = r2_score(y2_test,pred_rf3)
mae_rf3 = mean_absolute_error(y2_test,pred_rf3)

print("R2-score: ",r2_rf3)
print("MAE-score: ",mae_rf3)
# Out:
# R2-score:  0.988478064600959
# MAE-score:  0.31034978550908

# %% [markdown]
# Slight improvement from removing features.
#
# R2-score:  0.9884926172964775
#
# MAE-score:  0.31194108016110156

# %%
feature_names2 = X2[vars].columns
importances2 = rf3.feature_importances_
std = np.std([
    tree.feature_importances_ for tree in rf3.estimators_], axis=0)
forest_importances2 = pd.Series(importances2, index=feature_names2)
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
forest_importances2.plot.bar( ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
print(forest_importances2)
# Out:
# t2m               0.957901
# ssrd              0.001965
# tcc               0.001374
# week              0.001342
# t2mmax            0.016380
# t2mmin            0.009539
# t2min_previous    0.002986
# t2m_previous      0.001162
# t2min_next        0.003098
# t2m_next          0.004252
# dtype: float64

# %%
# index y_test to determine dates for case studies
days = pd.to_datetime(y2_test.index)
index_case1 = np.where((days>=datetime(2019,11,18)) & (days<=datetime(2019,11,24)))
input_case1 = pred_rf3[index_case1].flatten()

index_case2 = np.where((days>=datetime(2020,7,1)) & (days<=datetime(2020,7,9)))
input_case2 = pred_rf3[index_case2].flatten()

index_case3 = np.where((days>=datetime(2018,2,20)) & (days<=datetime(2018,3,19)))
input_case3 = pred_rf3[index_case3].flatten()

# %% [markdown]
# ### Case Study

# %%
RMS_based_eval(input_case1,"T2m","1","Random Forest")
# Out:
# [-0.3167571448401566, 0.5421515224143306]

# %%
RMS_based_eval(input_case2,"T2m","2","Random Forest")
# Out:
# [0.5651643671443523, 0.7842598551123351]

# %%
RMS_based_eval(input_case3,"T2m","3","Random Forest")
# Out:
# [-0.15278621809819515, 0.7162928193137383]

# %% [markdown]
# Cases 1 & 2 saw a small increase in performance, case 3 however saw a worsening in RMS.

# %%
se = (pred_rf - y_test)**2
se2 = (pred_rf2 - y_test)**2
se3 = (pred_rf3 - y_test)**2
se.index = pd.to_datetime(se.index)
se2.index = pd.to_datetime(se.index)
se3.index = pd.to_datetime(se.index)
mse_by_week = se.groupby(se.index.week).mean().mean(axis=1)
mse_by_week2 = se2.groupby(se2.index.week).mean().mean(axis=1)
mse_by_week3 = se3.groupby(se3.index.week).mean().mean(axis=1)
plt.plot(np.arange(0,53,1),mse_by_week.values.flatten(),linewidth=1)
plt.plot(np.arange(0,53,1),mse_by_week2.values.flatten(),linewidth=1)
plt.plot(np.arange(0,53,1),mse_by_week3.values.flatten(),linewidth=1)
plt.title("Weekly MSE Distribution: RF Predictions")
plt.xlabel("Week of Year")
plt.ylabel("MSE")
plt.legend(["Adding lag day","Adding precip/cloud","Feature reduction"])

# %% [markdown]
# There are no large improvements in the model from additional features nor from removal of features. If you want to be pedantic, there is a slight improvement in the winter months from feature reduction however it is miniscule.
